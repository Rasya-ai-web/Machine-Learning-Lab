# %% [markdown]
# <a href="https://colab.research.google.com/github/Rasya-ai-web/Machine-Learning-Lab/blob/main/ML_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Text Categorization using SVM

# %% [markdown]
# Import required libraries

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# Load the dataset

# %%
data = pd.read_csv("/content/statement_dataset_realistic_200.csv")

print("Dataset:")
print(data.head())

print("\nTotal number of records:", len(data))
# Out:
# Dataset:
#    ID                                              Text     Label
# 0   1                The product has good build quality  Positive
# 1   2            The quality was better than I expected  Positive
# 2   3           The instructions were clear and helpful  Positive
# 3   4       The support team gave an unhelpful response  Negative
# 4   5  The product design is confusing and inconvenient  Negative
#
# Total number of records: 200

# %% [markdown]
# Separate input and output

# %%
X = data["Text"]
y = data["Label"]

# %% [markdown]
# Split dataset into training and testing data

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("\nTraining records:", len(X_train))
print("Testing records :", len(X_test))
# Out:
# Training records: 160
# Testing records : 40

# %% [markdown]
# Convert text into numerical vectors
# using TF-IDF

# %%
vectorizer = TfidfVectorizer(
    lowercase=True,
    stop_words="english"
)

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print("\nTF-IDF Training Shape:", X_train_tfidf.shape)
print("TF-IDF Testing Shape :", X_test_tfidf.shape)
# Out:
# TF-IDF Training Shape: (160, 145)
# TF-IDF Testing Shape : (40, 145)

# %% [markdown]
# Create and train SVM model

# %%
model = SVC(kernel="linear")

model.fit(X_train_tfidf, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Predict test data

# %%
y_pred = model.predict(X_test_tfidf)

# %% [markdown]
# Calculate accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)

print("\nActual Labels    :", list(y_test))
print("Predicted Labels :", list(y_pred))

print("\nAccuracy:", accuracy)
print("Accuracy Percentage:", accuracy * 100, "%")
# Out:
# Actual Labels    : ['Negative', 'Positive', 'Positive', 'Positive', 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', 'Negative', 'Positive', 'Positive', 'Negative', 'Positive', 'Negative', 'Negative', 'Positive', 'Negative', 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Positive', 'Negative', 'Positive', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Positive', 'Negative']
# ...

# %% [markdown]
# Classification report

# %%
print("\nClassification Report:")
print(
    classification_report(
        y_test,
        y_pred,
        zero_division=0
    )
)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       1.00      0.85      0.92        20
#     Positive       0.87      1.00      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40

# %% [markdown]
# Test with new text

# %%
new_text = [
    "I really enjoyed this excellent product"
]

# Convert new text into TF-IDF vector
new_text_tfidf = vectorizer.transform(new_text)

# Predict category
prediction = model.predict(new_text_tfidf)

print("\nNew Text:", new_text[0])
print("Predicted Class:", prediction[0])
# Out:
# New Text: I really enjoyed this excellent product
# Predicted Class: Positive
